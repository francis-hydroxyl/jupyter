# %%
import astropy
import astropy.io.fits
import numpy as np
import matplotlib.pyplot as plt
import aplpy
import glob

# %%
galaxies=["ic5332", "ngc0628", "ngc1087", "ngc1300", "ngc1365", "ngc1385", "ngc1433", "ngc1512",
          "ngc1566", "ngc1672", "ngc2835", "ngc3351", "ngc3627", "ngc4254", "ngc4303", "ngc4321", 
          "ngc4535", "ngc5068", "ngc7496"]

# %% [markdown]
# # ic5332

# %%
gal_name = 'ic5332'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.8
color_max_R = 2.3
color_min_G = 0.2
color_max_G = 1.7
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="sqrt", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  8.000e-01 [aplpy.rgb]
# INFO: vmax =  2.300e+00 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  2.000e-01 [aplpy.rgb]
# INFO: vmax =  1.700e+00 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# /usr/local/lib/python3.8/dist-packages/astropy/visualization/mpl_normalize.py:180: RuntimeWarning: divide by zero encountered in divide
#   np.true_divide(values, self.vmax - self.vmin, out=values)
# WARNING: FITSFixedWarning: The WCS transformation has more axes (2) than the image it is associated with (0) [astropy.wcs.wcs]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
# ...

# %% [markdown]
# # ngc0628

# %%
gal_name = 'ngc0628'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.8
color_max_R = 4
color_min_G = 0.2
color_max_G = 6
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="sqrt", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  8.000e-01 [aplpy.rgb]
# INFO: vmax =  4.000e+00 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  2.000e-01 [aplpy.rgb]
# INFO: vmax =  6.000e+00 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc1087

# %%
gal_name = 'ngc1087'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 1
color_max_R = 18
color_min_G = 1
color_max_G = 15
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="sqrt", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e+00 [aplpy.rgb]
# INFO: vmax =  1.800e+01 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  1.000e+00 [aplpy.rgb]
# INFO: vmax =  1.500e+01 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc1300

# %%
gal_name = 'ngc1300'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0
color_max_R = 4
color_min_G = 0
color_max_G = 1.8
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="linear", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  4.000e+00 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  1.800e+00 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc1365

# %%
gal_name = 'ngc1365'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0
color_max_R = 6
color_min_G = 0.1
color_max_G = 4
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="linear", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  6.000e+00 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  4.000e+00 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc1385

# %%
gal_name = 'ngc1385'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0
color_max_R = 95
color_min_G = 0
color_max_G = 70
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="sqrt", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  9.500e+01 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  7.000e+01 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc1433

# %%
gal_name = 'ngc1433'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.1
color_max_R = 4
color_min_G = 0.4
color_max_G = 3.5
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="sqrt", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  4.000e+00 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  4.000e-01 [aplpy.rgb]
# INFO: vmax =  3.500e+00 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc1512

# %%
gal_name = 'ngc1512'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.2
color_max_R = 4
color_min_G = 0.2
color_max_G = 6
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="sqrt", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  2.000e-01 [aplpy.rgb]
# INFO: vmax =  4.000e+00 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  2.000e-01 [aplpy.rgb]
# INFO: vmax =  6.000e+00 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc1566

# %%
gal_name = 'ngc1566'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.1
color_max_R = 40
color_min_G = 0.2
color_max_G = 30
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="sqrt", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  4.000e+01 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  2.000e-01 [aplpy.rgb]
# INFO: vmax =  3.000e+01 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc1672

# %%
gal_name = 'ngc1672'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.1
color_max_R = 15
color_min_G = 0.4
color_max_G = 20
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="sqrt", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  1.500e+01 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  4.000e-01 [aplpy.rgb]
# INFO: vmax =  2.000e+01 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc2835

# %%
gal_name = 'ngc2835'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.1
color_max_R = 6
color_min_G = 0.2
color_max_G = 8
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="sqrt", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  6.000e+00 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  2.000e-01 [aplpy.rgb]
# INFO: vmax =  8.000e+00 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc3351

# %%
gal_name = 'ngc3351'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.1
color_max_R = 6
color_min_G = 0.4
color_max_G = 13
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="sqrt", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  6.000e+00 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  4.000e-01 [aplpy.rgb]
# INFO: vmax =  1.300e+01 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc3627

# %%
gal_name = 'ngc3627'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.1
color_max_R = 80
color_min_G = 2
color_max_G = 90
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="power", 
                     stretch_g="sqrt", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  8.000e+01 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  2.000e+00 [aplpy.rgb]
# INFO: vmax =  9.000e+01 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc4254

# %%
gal_name = 'ngc4254'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.1
color_max_R = 80
color_min_G = 2
color_max_G = 90
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="linear", 
                     stretch_g="linear", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  8.000e+01 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  2.000e+00 [aplpy.rgb]
# INFO: vmax =  9.000e+01 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc4303

# %%
gal_name = 'ngc4303'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.1
color_max_R = 60
color_min_G = 1
color_max_G = 30
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="linear", 
                     stretch_g="linear", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  6.000e+01 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  1.000e+00 [aplpy.rgb]
# INFO: vmax =  3.000e+01 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc4321

# %%
gal_name = 'ngc4321'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.1
color_max_R = 28
color_min_G = 0.5
color_max_G = 11
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="linear", 
                     stretch_g="linear", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  2.800e+01 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  5.000e-01 [aplpy.rgb]
# INFO: vmax =  1.100e+01 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc4535

# %%
gal_name = 'ngc4535'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.1
color_max_R = 20
color_min_G = 0.1
color_max_G = 11
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="linear", 
                     stretch_g="linear", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  2.000e+01 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  1.100e+01 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc5068

# %%
gal_name = 'ngc5068'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.1
color_max_R = 20
color_min_G = 0.1
color_max_G = 11
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="linear", 
                     stretch_g="linear", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  2.000e+01 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  1.100e+01 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...

# %% [markdown]
# # ngc7496

# %%
gal_name = 'ngc7496'
r_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f2100w*.fits')
g_path = glob.glob(
    f'/home/elmegreen/jupyter/research/Bubble_detection/Paper2/phangs_jwst/PHANGSData/{gal_name}/*f770w*.fits')

# FITSデータの読み込みと前処理
r_hdu = astropy.io.fits.open(r_path[0])[1]
g_hdu = astropy.io.fits.open(g_path[0])[1]
b_hdu = astropy.io.fits.open(g_path[0])[1]

# %%
color_min_R = 0.1
color_max_R = 18
color_min_G = 0.1
color_max_G = 7
# color_min_G = 1000
# color_max_G = 1000
color_min_B = 1000
color_max_B = 1000

# %%
colorval = "%.1f_%.1f_%.1f_%.1f_%.1f_%.1f"%(color_min_R, color_max_R, color_min_G, color_max_G, color_min_B, color_max_B)
save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
fitss = [r_path[0], g_path[0], g_path[0]]

aplpy.make_rgb_image(fitss, save_png_name, 
                     vmin_r=color_min_R, 
                     vmax_r=color_max_R,
                     vmin_g=color_min_G,
                     vmax_g=color_max_G, 
                     vmin_b=color_min_B, 
                     vmax_b=color_max_B, 
                     stretch_r="linear", 
                     stretch_g="linear", 
                     stretch_b="linear")
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  1.800e+01 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  1.000e-01 [aplpy.rgb]
# INFO: vmax =  7.000e+00 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  1.000e+03 [aplpy.rgb]
# INFO: vmax =  1.000e+03 [aplpy.rgb]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 5
#       2 save_png_name = f'RGB_fig_APLPY/{gal_name}_RG_{colorval}' + '.png'
#       3 fitss = [r_path[0], g_path[0], g_path[0]]
# ----> 5 aplpy.make_rgb_image(fitss, save_png_name,
#       6                      vmin_r=color_min_R,
#       7                      vmax_r=color_max_R,
#       8                      vmin_g=color_min_G,
#       9                      vmax_g=color_max_G,
#      10                      vmin_b=color_min_B,
#      11                      vmax_b=color_max_B,
# ...
